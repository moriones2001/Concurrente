# %% [markdown]
# <!-- PROFILE LINK -->
#
# <h1 style = "text-align:center; font-size: 30px">PROGRAMACIÓN CONCURRENTE Y DISTRIBUIDA</h1>
# <a href ="https://github.com/moriones2001">
# <img src="https://avatars.githubusercontent.com/u/100123414?v=4" style="float:left;vertical-align:centre" width="110" height="110" title = "Iván García Moriones 21907762">
# <a href ="https://github.com/moriones2001?tab=repositories">
# <img src="https://media-exp1.licdn.com/dms/image/C4D0BAQEu_Aa76fcmPw/company-logo_200_200/0/1630998679429?e=2159024400&v=beta&t=2feC9GG7RWCWizTqsK5HzDWB1TL2DOQuAVwnMf6FFvk" title = "M41" alt="UE" width="110" height="110" style="float:right;vertical-align:centre">

# %% [markdown]
# ## MI PC ES UNA MIERDA?

# %% [markdown]
# ## Before

# %%
from IPython import display as dp

# %%
dp.Image("Nucleosbefore.jpg")

# %% [markdown]
# ## After

# %%
def fib (n):
    if n in {0,1}:
        return 1
    else:
       return (fib(n-1)+fib(n-2))

# %% [markdown]
# fib (50)

# %%
dp.Image("Nucleosafter.jpg")

# %%
import threading as th

# %%
import multiprocessing as mp

# %%
mp.cpu_count
# Out:
# <bound method BaseContext.cpu_count of <multiprocessing.context.DefaultContext object at 0x0000021671F84460>>

# %%
mp.Pool
# Out:
# <bound method BaseContext.Pool of <multiprocessing.context.DefaultContext object at 0x0000021671F84460>>

# %%
git.remote.add
